# %% [markdown]
# # 📊 Week 3: Multi-Dataset Statistical Analysis
# Implementation based on Experiment 3 guidelines.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Load Supplemental Datasets
iris = pd.read_csv('datasets/Iris.csv')
diabetes = pd.read_csv('datasets/diabetes.csv')
mtcars = pd.read_csv('datasets/mtcars.csv')

print('Datasets loaded successfully.')

# %% [markdown]
# ## Correlation Matrix Analysis

# %%
plt.figure(figsize=(10,8))
sns.heatmap(diabetes.corr(), annot=True, cmap='RdYlGn')
plt.title('Diabetes Correlation Heatmap')
plt.show()
