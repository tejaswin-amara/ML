# %% [markdown]
# # 📊 Experiment 3: Advanced Data Analysis
# ### Objectives:
# - Descriptive Statistics
# - Bivariate Analysis
# - Correlation Heatmaps for Iris, Diabetes, and MTCars

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Function to perform full analysis sequence per document guidelines
def comprehensive_eda(file_path, title):
    df = pd.read_csv(file_path)
    print(f'--- {title} Dataset Statistics ---')
    print(df.info())
    display(df.describe())
    
    # Visualization sequence
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.boxplot(data=df.select_dtypes(include=[np.number]))
    plt.title(f'Outlier Detection: {title}')
    
    plt.subplot(1, 2, 2)
    sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
    plt.title(f'Feature Correlation: {title}')
    plt.show()

# Execute for all Week 3 datasets
datasets = ['datasets/Iris.csv', 'datasets/diabetes.csv', 'datasets/mtcars.csv']
for d in datasets:
    if os.path.exists(d):
        comprehensive_eda(d, os.path.basename(d))
